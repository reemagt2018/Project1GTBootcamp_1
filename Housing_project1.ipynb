# %%
# Create code to answer each of the following questions.
# Hint: You will need multiple target URLs and multiple API requests.

# Dependencies
import matplotlib.pyplot as plt

import requests
import json
import pprint as pprint

import pandas as pd
import numpy as np

import time
from datetime import datetime
# Google API Key
from config import gkey

# %%
# 1. What are the geocoordinates (latitude and longitude) of Seattle,
# Washington?
target_city = input("Please input the city where you would like to move : ")
radius=int(input("Please input the radius around the city : "))

params = {"address": target_city, "key": gkey}

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/geocode/json"

print(f" The Geocoordinates of {target_city} is")

# Run request
response = requests.get(base_url, params=params)
print(response)

# Convert to JSON
target_geo = response.json()
pprint.pprint(target_geo)

# Extract lat/lng
lat = target_geo["results"][0]["geometry"]["location"]["lat"]
lng = target_geo["results"][0]["geometry"]["location"]["lng"]
state=target_geo["results"][0]["address_components"][2]["short_name"]

# Print results
print(f"{target_city}: {lat}, {lng}, {state}")
# Out:
# Please input the city where you would like to move : atlanta
# Please input the radius around the city : 10000
#  The Geocoordinates of atlanta is
# <Response [200]>
# {'results': [{'address_components': [{'long_name': 'Atlanta',
#                                       'short_name': 'Atlanta',
#                                       'types': ['locality', 'political']},
#                                      {'long_name': 'Fulton County',
#                                       'short_name': 'Fulton County',
#                                       'types': ['administrative_area_level_2',
#                                                 'political']},
#                                      {'long_name': 'Georgia',
#                                       'short_name': 'GA',
#                                       'types': ['administrative_area_level_1',
#                                                 'political']},
#                                      {'long_name': 'United States',
#                                       'short_name': 'US',
#                                       'types': ['country', 'political']}],
#               'formatted_address': 'Atlanta, GA, USA',
#               'geometry': {'bounds': {'northeast': {'lat': 33.8876179,
#                                                     'lng': -84.289389},
#                                       'southwest': {'lat': 33.6478079,
#                                                     'lng': -84.5518189}},
#                            'location': {'lat': 33.7489954, 'lng': -84.3879824},
#                            'location_type': 'APPROXIMATE',
#                            'viewport': {'northeast': {'lat': 33.8876179,
#                                                       'lng': -84.289389},
#                                         'southwest': {'lat': 33.6478079,
#                                                       'lng': -84.5518189}}},
#               'place_id': 'ChIJjQmTaV0E9YgRC2MLmS_e_mY',
#               'types': ['locality', 'political']}],
#  'status': 'OK'}
# atlanta: 33.7489954, -84.3879824, GA

# %%
type(lat)
# Out:
# float

# %%
#postal_code

#Find the zip code in the given radius.
#    Hint: See https://developers.google.com/places/web-service/supported_types

print(f"{target_city}: {lat}, {lng}, {state}")
target_type = "store"
target_coords = str(lat)+", " + str(lng)
print(type(target_coords))
radius = radius


# rewrite params dict

params = {
   "location": target_coords,
   "types": target_type,
    "radius": radius,
    "key": gkey
}

print(f"{params}")

# Build URL using the Google Maps API
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"


# Run request
response = requests.get(base_url, params)

# print the response URL, avoid doing for public GitHub repos in order to avoid exposing key
print(response.url)

print(f"All zip codes in vicinity of {target_city}, {state}")

Zip_codes = response.json()

# Print the JSON (pretty printed)
pprint.pprint(f"{Zip_codes}")

# Print the name and address of the first bike shop to appear
print(seattle_bikes["results"][0]["name"])
print(seattle_bikes["results"][0]["vicinity"])
# Out:
# atlanta: 33.7489954, -84.3879824, GA
# <class 'str'>
# {'location': '33.7489954, -84.3879824', 'types': 'store', 'radius': 10000, 'key': 'AIzaSyBzySC6G8D4K1AebQKATqfvpshOOjzT0yg'}
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.7489954%2C+-84.3879824&types=store&radius=10000&key=AIzaSyBzySC6G8D4K1AebQKATqfvpshOOjzT0yg
# All zip codes in vicinity of atlanta, GA
# ("{'html_attributions': [], 'next_page_token': "
#  "'CqQCHgEAAELxWBVs6DLQEsiqzlvaG6_hD7CKurJ1R9oGLkmWrO3yoA1ZggH1_VwxzUg5GZo4vZLpl9_zKcDClzLm9IIBeY6D5FbYUWvSD_PRxm2DtgF6Ip9U2aqX6MV9g9ipidmREXo-fE898uA5W1TCbM5HorNenJsGJ_IwFRtpN-XMteDmVdzA9fuCNPDckRDHkq5CPW05fz1SUfnO2aKSyzZe1y5B3O4VI6nWt2pwY7NV2bEUtnh3GWAyWug4JDZdKxOt_Asmqy0zOHrJra1TyGuHe_Zi_rvw_BIZQpC7oyjtXDlIEXhdQLn27qmUExLPl8ckNY_-8A-MU7l3dftI0O3TORzVFkdAIHYyOvqdSaPNV4Xigud0FFnMUlAdBMScAsjY8xIQ2Yq2-MJ3lEiPSj6zqX8mkBoUo7qVrvLEoUzCBuxPzkpR-SnrIWE', "
#  "'results': [{'geometry': {'location': {'lat': 33.7567264, 'lng': "
#  "-84.3461284}, 'viewport': {'northeast': {'lat': 33.7583696302915, 'lng': "
#  "-84.3450720197085}, 'southwest': {'lat': 33.7556716697085, 'lng': "
#  "-84.3477699802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'41e8ca5f7b1e91de20eb92ec390400b1f06ab16a', 'name': 'Target', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 1080, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/104403812106867895322/photos">Vanessa '
#  "Rivera</a>'], 'photo_reference': "
#  "'CmRaAAAASis74DMkfb-fOQT07RXSpubCh4y5BJY0f6CNsN7wnHlAWSZdtMJuo3Zlip3BYBWkKnODBvQVFmHICWzby2FAQHUGKaeN257d9dTzDCCp7gXdoP7tJZei3_3xQIrZOpEZEhBwRjnCEFfPzl9ZXPQ-bTEAGhQelEVwUka0mpwqKlYhmW9hL4IDGA', "
#  "'width': 1920}], 'place_id': 'ChIJsfsr1awG9YgR8EBuqmmg5m0', 'plus_code': "
#  "{'compound_code': 'QM43+MG Atlanta, Georgia, United States', 'global_code': "
#  "'865QQM43+MG'}, 'price_level': 2, 'rating': 4.1, 'reference': "
#  "'ChIJsfsr1awG9YgR8EBuqmmg5m0', 'scope': 'GOOGLE', 'types': "
#  "['department_store', 'furniture_store', 'grocery_or_supermarket', "
#  "'clothing_store', 'electronics_store', 'home_goods_store', 'store', 'food', "
#  "'point_of_interest', 'establishment'], 'vicinity': '1275 Caroline Street "
#  "Northeast, Atlanta'}, {'geometry': {'location': {'lat': 33.777217, 'lng': "
#  "-84.3663263}, 'viewport': {'northeast': {'lat': 33.77860278029149, 'lng': "
#  "-84.36474076970849}, 'southwest': {'lat': 33.7759048197085, 'lng': "
#  "-84.3674387302915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'217bfafe1168403d39c3af65eb9db1fcad5c25b7', 'name': 'The Home Depot', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 1080, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/111350701803063020573/photos">Duran '
#  "Aaron</a>'], 'photo_reference': "
#  "'CmRZAAAAn1BacFrGAWg75KWRs77GnarVWHFP4wuE45t6gFyuh7Gerw2Cf8coL3S8rfolo9J4szW69adAzAn5lHM96nq1sBmCxp2v_4-J5jM8ZCEK_Hbds5B5azdkHc-tPav6c5lwEhAyS06DOxRBCD37HIWUGvJxGhThU7JyevGQ7n2q6fZGFQhCw3spbQ', "
#  "'width': 1920}], 'place_id': 'ChIJ6cBjtBAE9YgRC3ard6hoQAI', 'plus_code': "
#  "{'compound_code': 'QJGM+VF Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJGM+VF'}, 'price_level': 1, 'rating': 4, 'reference': "
#  "'ChIJ6cBjtBAE9YgRC3ard6hoQAI', 'scope': 'GOOGLE', 'types': "
#  "['hardware_store', 'home_goods_store', 'store', 'point_of_interest', "
#  "'establishment'], 'vicinity': '650 Ponce De Leon Avenue Northeast, "
#  "Atlanta'}, {'geometry': {'location': {'lat': 33.8238516, 'lng': "
#  "-84.3629766}, 'viewport': {'northeast': {'lat': 33.8253818302915, 'lng': "
#  "-84.36173366970849}, 'southwest': {'lat': 33.8226838697085, 'lng': "
#  "-84.36443163029149}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'6b7933f4ec45b3f454399e86f2f852210ce435f2', 'name': 'Target', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 3744, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/114954816439207979528/photos">Cecil '
#  "Glenn</a>'], 'photo_reference': "
#  "'CmRaAAAAIXR-U2Ad7y5sr-s3zITF6cFCvDsInR4elYaTmL3gPnrsNa5JVrVx-X-XbBNkYMeZBZ96VKyvJ12BMWEGfYw9glF2LNsj_me_qKKRs7xisEzxnwrchk7ALNnGsD-UnrXLEhBiwiykwN078Eohjd-vA-WgGhQxp7YBeqoI3Uk1Ie7sxZXsR_jjPA', "
#  "'width': 5616}], 'place_id': 'ChIJl2QegcIF9YgRH-A4MIhcMIc', 'plus_code': "
#  "{'compound_code': 'RJFP+GR Atlanta, Georgia, United States', 'global_code': "
#  "'865QRJFP+GR'}, 'price_level': 2, 'rating': 4.1, 'reference': "
#  "'ChIJl2QegcIF9YgRH-A4MIhcMIc', 'scope': 'GOOGLE', 'types': "
#  "['department_store', 'furniture_store', 'grocery_or_supermarket', "
#  "'clothing_store', 'electronics_store', 'home_goods_store', 'store', 'food', "
#  "'point_of_interest', 'establishment'], 'vicinity': '2539 Piedmont Rd NE, "
#  "Atlanta'}, {'geometry': {'location': {'lat': 33.764726, 'lng': -84.333199}, "
#  "'viewport': {'northeast': {'lat': 33.7661325802915, 'lng': "
#  "-84.3318512197085}, 'southwest': {'lat': 33.7634346197085, 'lng': "
#  "-84.3345491802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': "
#  "'5467df081a0b1df8b11a66358b337fe0acc36285', 'name': 'The Flying Biscuit "
#  "Cafe', 'opening_hours': {'open_now': True}, 'photos': [{'height': 4032, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/101207741618853361217/photos">Serenidad '
#  "Oquendo</a>'], 'photo_reference': "
#  "'CmRaAAAALI78ljZjp-ImtFg8RVrwMDJV0DCNw05k_03MhC0pfC6reoOktKs7OXAl9NgkvokxiqlBtOstkaVWmqxqj6JfxUL1lF8vT7tPtTckA589wmPlbFJpxPUXeHi9Z1jWdmYmEhB5d8ubFF2PQmi_d0DfyXVrGhQyINYWRVG-EnMXFHyLkYUKRhQ0ug', "
#  "'width': 3024}], 'place_id': 'ChIJBQ4s1rcG9YgREInZmqH3JKg', 'plus_code': "
#  "{'compound_code': 'QM78+VP Atlanta, Georgia, United States', 'global_code': "
#  "'865QQM78+VP'}, 'price_level': 2, 'rating': 4.5, 'reference': "
#  "'ChIJBQ4s1rcG9YgREInZmqH3JKg', 'scope': 'GOOGLE', 'types': ['meal_delivery', "
#  "'cafe', 'bakery', 'store', 'restaurant', 'food', 'point_of_interest', "
#  "'establishment'], 'vicinity': '1655 McLendon Avenue Northeast, Atlanta'}, "
#  "{'geometry': {'location': {'lat': 33.792604, 'lng': -84.395535}, 'viewport': "
#  "{'northeast': {'lat': 33.79385013029149, 'lng': -84.39418916970848}, "
#  "'southwest': {'lat': 33.79115216970849, 'lng': -84.3968871302915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'127efebdece4b476f4fb0ec90df89f94e2d8bb79', 'name': 'H&M', 'opening_hours': "
#  "{'open_now': True}, 'photos': [{'height': 2448, 'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/103467724962358246356/photos">Jessica '
#  "Richardson</a>'], 'photo_reference': "
#  "'CmRaAAAAZFL2vLYeFkndxs6u0YGekjAzaTeYYqn2HGv_H81U7FKXFpb68TuXNo7HyVyJLB_YJ-RloUiYz_FptG2KGKWZm3gcIxKJ73qdBt0qJ864b3j12a78FZND3jhAHSTwy_qvEhAMFC6hmST4CZuQPxKxv_8PGhTcTd8kbg6FpFremI-IjSFIxmDzXA', "
#  "'width': 3264}], 'place_id': 'ChIJiass9FcE9YgRyXYvyPoyd-E', 'plus_code': "
#  "{'compound_code': 'QJV3+2Q Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJV3+2Q'}, 'price_level': 1, 'rating': 3.4, 'reference': "
#  "'ChIJiass9FcE9YgRyXYvyPoyd-E', 'scope': 'GOOGLE', 'types': "
#  "['clothing_store', 'store', 'point_of_interest', 'establishment'], "
#  "'vicinity': '231 18th Street Northwest, Atlanta'}, {'geometry': {'location': "
#  "{'lat': 33.7540928, 'lng': -84.37987679999999}, 'viewport': {'northeast': "
#  "{'lat': 33.7555759802915, 'lng': -84.37852516970848}, 'southwest': {'lat': "
#  "33.7528780197085, 'lng': -84.38122313029149}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'fc82de133308e8ebd39c66fd388d9ccada30ddc9', 'name': 'Sweet Auburn Curb "
#  "Market', 'opening_hours': {'open_now': False}, 'photos': [{'height': 2160, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/112695120140681178296/photos">Diana '
#  "Thurmann</a>'], 'photo_reference': "
#  "'CmRaAAAA4KDKrzFc3sAgPz2foDTFN2yzmFcw4J8FVbR5yxkFWs6PAvppeHYwVVV6Jor9JcZpaEzpQ2FAS2umS2Y1OducCDwuBvseZBNu6nHw0gcveC0yKWk5QG6_zfFkHy6cycd9EhDugOUFS3QxkxlvB16oFadfGhRUyjh6hjAmGpSckNW3o7cmG5M6mw', "
#  "'width': 3840}], 'place_id': 'ChIJPa8F3YsD9YgRpjPDbxOChoc', 'plus_code': "
#  "{'compound_code': 'QJ3C+J2 Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJ3C+J2'}, 'rating': 4.5, 'reference': 'ChIJPa8F3YsD9YgRpjPDbxOChoc', "
#  "'scope': 'GOOGLE', 'types': ['grocery_or_supermarket', 'store', 'food', "
#  "'point_of_interest', 'establishment'], 'vicinity': '209 Edgewood Avenue "
#  "Southeast, Atlanta'}, {'geometry': {'location': {'lat': 33.7804012, 'lng': "
#  "-84.36859969999999}, 'viewport': {'northeast': {'lat': 33.7816019302915, "
#  "'lng': -84.36725271970849}, 'southwest': {'lat': 33.7789039697085, 'lng': "
#  "-84.3699506802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', "
#  "'id': 'e4c58f79be03fc646f5628a05979e060e6b4228d', 'name': 'The UPS Store', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 607, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/115840241632195669829/photos">The '
#  "UPS Store</a>'], 'photo_reference': "
#  "'CmRaAAAA3ZeVeyzsOzpzeq0F6-Ha2LkZVWmiE9Bdce9tpnpKFeREx_Z5jGLY4QMp07WmAuX7pmIKWUIa8Fv51aaEawEnaJFqoGPBi5UVQOqV9Q_p4uHUW-C6vv695Gr5fU2LqUT6EhBVffoTNa2fyj2pPE7VZJJjGhToGC5yV2Bx9XIYOM9HyxZ9ZC23cQ', "
#  "'width': 1080}], 'place_id': 'ChIJJYpfLxYE9YgRuhr0voi5S50', 'plus_code': "
#  "{'compound_code': 'QJJJ+5H Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJJJ+5H'}, 'price_level': 2, 'rating': 4, 'reference': "
#  "'ChIJJYpfLxYE9YgRuhr0voi5S50', 'scope': 'GOOGLE', 'types': ['finance', "
#  "'store', 'point_of_interest', 'establishment'], 'vicinity': '931 Monroe "
#  "Drive Northeast #102, Atlanta'}, {'geometry': {'location': {'lat': "
#  "33.78886780000001, 'lng': -84.4052687}, 'viewport': {'northeast': {'lat': "
#  "33.7898769802915, 'lng': -84.40355491970848}, 'southwest': {'lat': "
#  "33.7871790197085, 'lng': -84.4062528802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'96419c19664b5cfb4080e5d112fe1b7a9347c3c7', 'name': 'IKEA Atlanta Home "
#  "Furnishings', 'opening_hours': {'open_now': True}, 'photos': [{'height': "
#  "3120, 'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/116164966962680664701/photos">Sandeep '
#  "Gunda</a>'], 'photo_reference': "
#  "'CmRaAAAAOoJREsOXU3cSPMtpy5Sk-h2NOzmZzyDNFNnpy9Q1P5h1gzvWdyRueOVS87cgZcUhnU-1dAB4Ardp2FGVW05W8KopGWba3KJOjgJDcJoNbz6F5J4NJjhrcK8VPXg4pGcSEhBrYBMAGKIUO7UqGrhWSNZGGhSdWkKm7E98N-muntiEFwK_obaCbw', "
#  "'width': 4160}], 'place_id': 'ChIJCULE-vEE9YgRkFJI5PPi7fw', 'plus_code': "
#  "{'compound_code': 'QHQV+GV Atlanta, Georgia, United States', 'global_code': "
#  "'865QQHQV+GV'}, 'rating': 4.3, 'reference': 'ChIJCULE-vEE9YgRkFJI5PPi7fw', "
#  "'scope': 'GOOGLE', 'types': ['furniture_store', 'home_goods_store', 'store', "
#  "'point_of_interest', 'establishment'], 'vicinity': '441 16th Street "
#  "Northwest, Atlanta'}, {'geometry': {'location': {'lat': 33.7869045, 'lng': "
#  "-84.3840816}, 'viewport': {'northeast': {'lat': 33.7883486802915, 'lng': "
#  "-84.38234936970848}, 'southwest': {'lat': 33.7856507197085, 'lng': "
#  "-84.3850473302915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': "
#  "'fc5ccb0a80904edb9e219ff05a081248e6522a2c', 'name': 'Highland Bakery', "
#  "'opening_hours': {'open_now': False}, 'photos': [{'height': 4128, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/104530766392966637683/photos">Kelvin '
#  "Bragg</a>'], 'photo_reference': "
#  "'CmRaAAAA97TyJiJgcmv2bBvSZEY1Y_bEdrrf_bXhLuAQgsYlKSWy7UGZU_yiKRF3P9kCPcNZY9hp1uBDansSiThsKODg3BF-0cYbuoBbD_qeZiI67JDb5lRu81YuYSnG3_BiCQXUEhAN9-3DhGohrO8u8PW_89nTGhSEHvsHwqnT6RSlJeJDLaZlr0b7xg', "
#  "'width': 3096}], 'place_id': 'ChIJ6XhehUQE9YgRwkLE4WTj3Fk', 'plus_code': "
#  "{'compound_code': 'QJP8+Q9 Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJP8+Q9'}, 'price_level': 1, 'rating': 4, 'reference': "
#  "'ChIJ6XhehUQE9YgRwkLE4WTj3Fk', 'scope': 'GOOGLE', 'types': ['bakery', "
#  "'store', 'restaurant', 'food', 'point_of_interest', 'establishment'], "
#  "'vicinity': '1180 Peachtree Street Northeast, Atlanta'}, {'geometry': "
#  "{'location': {'lat': 33.7931925, 'lng': -84.3992682}, 'viewport': "
#  "{'northeast': {'lat': 33.7941699802915, 'lng': -84.39826141970849}, "
#  "'southwest': {'lat': 33.7914720197085, 'lng': -84.4009593802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'699048907a616d4f631b35d0b72870466799f1d9', 'name': 'Target', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 1080, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/114946327598847576108/photos">sanika '
#  "Wadekar</a>'], 'photo_reference': "
#  "'CmRaAAAAGuZ_oW0ziySBqMKnr-Ogdc_EkWEN2Cx3tm2xdlicXP68Cglgdb20be_fpE8iIFDm-r2TubudXpGshF5wYnQZMWBQVZu0sZuI2NtP35cEj8xHe72iBXGeqAGgZI4vpV3oEhC6REKmVeJE8eaH2Ka5sjGoGhTqfU4xw_GRe9aEjQg4AQyESZp17Q', "
#  "'width': 1920}], 'place_id': 'ChIJtz7EAvgE9YgRpAfjroQBEzE', 'plus_code': "
#  "{'compound_code': 'QJV2+77 Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJV2+77'}, 'price_level': 2, 'rating': 4.1, 'reference': "
#  "'ChIJtz7EAvgE9YgRpAfjroQBEzE', 'scope': 'GOOGLE', 'types': "
#  "['department_store', 'furniture_store', 'grocery_or_supermarket', "
#  "'clothing_store', 'electronics_store', 'home_goods_store', 'store', 'food', "
#  "'point_of_interest', 'establishment'], 'vicinity': '375 18th Street "
#  "Northwest, Atlanta'}, {'geometry': {'location': {'lat': 33.8238093, 'lng': "
#  "-84.3631917}, 'viewport': {'northeast': {'lat': 33.8253601302915, 'lng': "
#  "-84.3618255697085}, 'southwest': {'lat': 33.8226621697085, 'lng': "
#  "-84.3645235302915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'35aa94fd551fc473ed02aab1bc72698b6605911c', 'name': 'Best Buy', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 1080, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/114134791089044691189/photos">Michael '
#  "Doherty</a>'], 'photo_reference': "
#  "'CmRaAAAAlPGdPGZHPRqPd1lxPe9nHmvk6ahFZvHbTU4RHn1HQ9ezu0wfHkmfbcQuaVwyJjlB-5f-p6GiwutppOb1VJKbrP9ezFHrGIZ2egxgdGbfECaLx-yqEWasliV4Lt5O2uUgEhAy6dM4xuh1kxdBHsvRcRGXGhTcUrzkyWHOzVlbtld8iO3jcNJDTg', "
#  "'width': 1920}], 'place_id': 'ChIJEX0ZXt0F9YgRZRYvvB0g75o', 'plus_code': "
#  "{'compound_code': 'RJFP+GP Atlanta, Georgia, United States', 'global_code': "
#  "'865QRJFP+GP'}, 'price_level': 2, 'rating': 4.2, 'reference': "
#  "'ChIJEX0ZXt0F9YgRZRYvvB0g75o', 'scope': 'GOOGLE', 'types': "
#  "['electronics_store', 'home_goods_store', 'store', 'point_of_interest', "
#  "'establishment'], 'vicinity': '2537 Piedmont Road Northeast, Atlanta'}, "
#  "{'geometry': {'location': {'lat': 33.7586647, 'lng': -84.3914487}, "
#  "'viewport': {'northeast': {'lat': 33.7599415802915, 'lng': "
#  "-84.3900183697085}, 'southwest': {'lat': 33.7572436197085, 'lng': "
#  "-84.39271633029152}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png', "
#  "'id': '4d6df97d5da68f77a422fffeaf6fb2c5fb30d439', 'name': 'Tabernacle', "
#  "'photos': [{'height': 1365, 'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/110655138611949816955/photos">Tabernacle</a>\'], '
#  "'photo_reference': "
#  "'CmRaAAAAsj7n7kUCKyePLSKYjCHmh1cBdVcpu51rSGs4dWDCbB2sE3szyaSlKFk5MmjRmGRjDpblNgs-bMY54U-vgMrzYxrNk9ZA125xpKk0VgkXqksHbaIoLdpawz-ckAXt588BEhBpvhAux2kFND2LN2V4e-KyGhR6l3e0vejjllFBUjrE9vwMp7HdPA', "
#  "'width': 2048}], 'place_id': 'ChIJ1Q3ZVn8E9YgRxZ015hv_l-w', 'plus_code': "
#  "{'compound_code': 'QJ55+FC Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJ55+FC'}, 'price_level': 3, 'rating': 4.6, 'reference': "
#  "'ChIJ1Q3ZVn8E9YgRxZ015hv_l-w', 'scope': 'GOOGLE', 'types': ['store', "
#  "'point_of_interest', 'establishment'], 'vicinity': '152 Luckie Street "
#  "Northwest, Atlanta'}, {'geometry': {'location': {'lat': 33.7560658, 'lng': "
#  "-84.34807219999999}, 'viewport': {'northeast': {'lat': 33.7576075302915, "
#  "'lng': -84.34672116970849}, 'southwest': {'lat': 33.7549095697085, 'lng': "
#  "-84.3494191302915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'037719c386bc7d9e3b97b6d022a049a11c02102c', 'name': 'Kroger', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 1128, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/104548230555925336799/photos">Kroger</a>\'], '
#  "'photo_reference': "
#  "'CmRaAAAA5Uer1RhOYiU0F52OEs5PkpzRRXawPnFNM4JE_KjjzYnW688LCWYznyXkta1FOPb4qtVgLRXASVOsMYI5VMI0SJDpUZ9_LKibOoiKWBDsO3Rm_Uwn-aBNpyVNXXZTTWoGEhBO0hcBESjuNPfvLPNCp5K0GhSg3QveBe4BQSYefDYPt3sqzryxhA', "
#  "'width': 1782}], 'place_id': 'ChIJKznvTVMB9YgRWFYyoZFkjyk', 'plus_code': "
#  "{'compound_code': 'QM42+CQ Atlanta, Georgia, United States', 'global_code': "
#  "'865QQM42+CQ'}, 'price_level': 2, 'rating': 4.2, 'reference': "
#  "'ChIJKznvTVMB9YgRWFYyoZFkjyk', 'scope': 'GOOGLE', 'types': "
#  "['grocery_or_supermarket', 'store', 'food', 'point_of_interest', "
#  "'establishment'], 'vicinity': '1225 Caroline Street Northeast, Atlanta'}, "
#  "{'geometry': {'location': {'lat': 33.78323959999999, 'lng': -84.3836401}, "
#  "'viewport': {'northeast': {'lat': 33.7846163802915, 'lng': "
#  "-84.38237101970849}, 'southwest': {'lat': 33.7819184197085, 'lng': "
#  "-84.3850689802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png', 'id': "
#  "'a31692d2d9e50add7dd086ec05e4949589f8e912', 'name': 'Cafe Intermezzo', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/113770545533353017036/photos">Jason '
#  "Mansfield</a>'], 'photo_reference': "
#  "'CmRaAAAAUnWGklyK3dfYJ8-YnwRe8QXwbHf56R9j_5YTE1dIWk9UQBhhHWPUbccwkYu80HRZSxbArMMca1WBd80fJ2Bq40iGOckJXxHsFzIkOa5HZmVQFLkyI-E4iBiueIMZSjV9EhBfSu0k6lG4BWsPSSc81xTxGhTWIxj-mxU3vMdWokl1hrBrk1jBwg', "
#  "'width': 4032}], 'place_id': 'ChIJicBn_aoF9YgRya-jWCHOmB0', 'plus_code': "
#  "{'compound_code': 'QJM8+7G Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJM8+7G'}, 'price_level': 2, 'rating': 4.4, 'reference': "
#  "'ChIJicBn_aoF9YgRya-jWCHOmB0', 'scope': 'GOOGLE', 'types': ['restaurant', "
#  "'cafe', 'store', 'food', 'point_of_interest', 'establishment'], 'vicinity': "
#  "'1065 Peachtree Street Northeast, Atlanta'}, {'geometry': {'location': "
#  "{'lat': 33.7775807, 'lng': -84.3848336}, 'viewport': {'northeast': {'lat': "
#  "33.7789154302915, 'lng': -84.38326701970848}, 'southwest': {'lat': "
#  "33.77621746970851, 'lng': -84.38596498029149}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'c09d1585728a248c141e78b2e6c80db2150a8af5', 'name': 'CVS', 'opening_hours': "
#  "{'open_now': True}, 'photos': [{'height': 3036, 'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/116153564359477814846/photos">David '
#  "Simon</a>'], 'photo_reference': "
#  "'CmRaAAAAP9ym7-15dhUXbFoKM2JjVDcy3xrZ_B_MJpyU3C_WLHtDjekMvLUJEnUNjdTlQ3wIuoVzmfv6cxAYmujrUNFq_QbdlWqxNR3Zy7cv3T6bHaGw5jWIQDCw73-AVizRYPiyEhCUXOUU6RA8hCiqpbkLdF9EGhTsLLwP6q22hvUXeeYGQaB6yKJ43g', "
#  "'width': 4048}], 'place_id': 'ChIJmw3himgE9YgRcxMlMqy-iHY', 'plus_code': "
#  "{'compound_code': 'QJH8+23 Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJH8+23'}, 'rating': 3.8, 'reference': 'ChIJmw3himgE9YgRcxMlMqy-iHY', "
#  "'scope': 'GOOGLE', 'types': ['convenience_store', 'store', 'health', 'food', "
#  "'point_of_interest', 'establishment'], 'vicinity': '842 Peachtree Street "
#  "Northeast, Atlanta'}, {'geometry': {'location': {'lat': 33.7791329, 'lng': "
#  "-84.3840732}, 'viewport': {'northeast': {'lat': 33.7804818802915, 'lng': "
#  "-84.38272421970849}, 'southwest': {'lat': 33.7777839197085, 'lng': "
#  "-84.3854221802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'b57663f675d7b5f06cfb06774f989e532c65b278', 'name': 'T-Mobile', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 2988, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/102920950571881624841/photos">Jeremiah '
#  "Kinser</a>'], 'photo_reference': "
#  "'CmRaAAAAX_b5P3ykjF4TEdCQsqqu3OEFh1rA8SaZBqusRTLOQNM55nSks3YGbOjuDyMfuxM7Lw8FtmtN8EGom9gCfHakojqgbA6K0GckVJ3kWX0pl2YeBoVtOw4CxeioOURHeCKSEhB_f1tC4SsfcWGaXBjuMg1CGhSUAhTIzQAVR2_s0oqxtx8aNSmHTA', "
#  "'width': 5312}], 'place_id': 'ChIJS6cTP2gE9YgR0XkGBfOS3pQ', 'plus_code': "
#  "{'compound_code': 'QJH8+M9 Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJH8+M9'}, 'price_level': 2, 'rating': 3.7, 'reference': "
#  "'ChIJS6cTP2gE9YgR0XkGBfOS3pQ', 'scope': 'GOOGLE', 'types': "
#  "['electronics_store', 'store', 'point_of_interest', 'establishment'], "
#  "'vicinity': '903 West Peachtree Street Northwest #500, Atlanta'}, "
#  "{'geometry': {'location': {'lat': 33.7751133, 'lng': -84.3657683}, "
#  "'viewport': {'northeast': {'lat': 33.7764236802915, 'lng': "
#  "-84.3646279697085}, 'southwest': {'lat': 33.7737257197085, 'lng': "
#  "-84.36732593029151}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'20f1520784106bf67f5a3825095499f696183c4c', 'name': 'Whole Foods Market', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/104240641329606982825/photos">Devin '
#  "Hagans</a>'], 'photo_reference': "
#  "'CmRaAAAASN_lItiOFIMLlPLWaEy5Wdq-dgynkS9VBeZU5IwFZYYEWF32j2UuU223_tt5EJu3sp5JKbiGfdOv8uLzYwlg5ZvfCgqZEVJ8Nnwop3DCll4FsJqbwfjn7WaJv8lOsndhEhCR-gYHDSeaIFeEOjtr7gmOGhQ1l6y3znkyfOJEPrk4t1KE0YD0eA', "
#  "'width': 4032}], 'place_id': 'ChIJ6cBjtBAE9YgRUisH70GZTX4', 'plus_code': "
#  "{'compound_code': 'QJGM+2M Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJGM+2M'}, 'price_level': 1, 'rating': 4.3, 'reference': "
#  "'ChIJ6cBjtBAE9YgRUisH70GZTX4', 'scope': 'GOOGLE', 'types': "
#  "['grocery_or_supermarket', 'supermarket', 'store', 'health', 'food', "
#  "'point_of_interest', 'establishment'], 'vicinity': '650 Ponce De Leon Avenue "
#  "Northeast, Atlanta'}, {'geometry': {'location': {'lat': 33.757832, 'lng': "
#  "-84.3488289}, 'viewport': {'northeast': {'lat': 33.7591809802915, 'lng': "
#  "-84.34747991970849}, 'southwest': {'lat': 33.7564830197085, 'lng': "
#  "-84.3501778802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'cf2de1427b1f6a996267db60ba622d1aa6f575de', 'name': 'Barnes & Noble', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 3120, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/101546466882236509071/photos">Angel '
#  "Askew</a>'], 'photo_reference': "
#  "'CmRaAAAAovAPyt3RYR-RWOmsztMKSet7LqUwxMMHrHGLIffn3043lgxrMu1nrStvxTY0RpRIQah_y_Wv6BXRQicfx6CKWW_Ns2Q8dYdQZgG215VYwFeYgMmfLX0etA4IP9jut8_qEhBqiloTstLfZoIwY6pWvauDGhRB88shoUiXS7qFfAvCW1_LYnv8BA', "
#  "'width': 4160}], 'place_id': 'ChIJkYxwnawG9YgR7u8o6dAhFTA', 'plus_code': "
#  "{'compound_code': 'QM52+4F Atlanta, Georgia, United States', 'global_code': "
#  "'865QQM52+4F'}, 'price_level': 2, 'rating': 4.5, 'reference': "
#  "'ChIJkYxwnawG9YgR7u8o6dAhFTA', 'scope': 'GOOGLE', 'types': ['book_store', "
#  "'electronics_store', 'home_goods_store', 'store', 'point_of_interest', "
#  "'establishment'], 'vicinity': '1217 Caroline Street Northeast, Atlanta'}, "
#  "{'geometry': {'location': {'lat': 33.8030534, 'lng': -84.4116942}, "
#  "'viewport': {'northeast': {'lat': 33.8042972802915, 'lng': "
#  "-84.4105052197085}, 'southwest': {'lat': 33.8015993197085, 'lng': "
#  "-84.4132031802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  "'f70edaf329b6c231fff5acca66e9b79aadc4e1b3', 'name': 'Walmart Supercenter', "
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 2988, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/110880696910899469293/photos">Angel '
#  "Shannon</a>'], 'photo_reference': "
#  "'CmRaAAAAP3-8f66x6D35_OFvIVDU_ReG-CEhV2I_dSHyZXyyGBhIpk649HaNN0zUOmmE4oaDLdlzLntdNpFpaBcd55HlqNmcdQxyWqbDLrzvvWjccxAboqipyWxWldfrTyIKvLUZEhDgBznh7u6fq8BynbM9DN7rGhT-IpcxlK8dg9cOkt4VDh1rJMPnfQ', "
#  "'width': 5312}], 'place_id': 'ChIJb2lkfesE9YgRtxIhLF6Yin0', 'plus_code': "
#  "{'compound_code': 'RH3Q+68 Atlanta, Georgia, United States', 'global_code': "
#  "'865QRH3Q+68'}, 'price_level': 1, 'rating': 3.7, 'reference': "
#  "'ChIJb2lkfesE9YgRtxIhLF6Yin0', 'scope': 'GOOGLE', 'types': "
#  "['department_store', 'supermarket', 'grocery_or_supermarket', "
#  "'electronics_store', 'store', 'food', 'point_of_interest', 'establishment'], "
#  "'vicinity': '1801 Howell Mill Road Northwest, Atlanta'}, {'geometry': "
#  "{'location': {'lat': 33.7796726, 'lng': -84.36758300000001}, 'viewport': "
#  "{'northeast': {'lat': 33.7810227302915, 'lng': -84.36645991970849}, "
#  "'southwest': {'lat': 33.7783247697085, 'lng': -84.3691578802915}}}, 'icon': "
#  "'https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png', 'id': "
#  '\'c1abc032a3e9b59bc92f4b9087ea1ac4ae9aa6dc\', \'name\': "Trader Joe\'s", '
#  "'opening_hours': {'open_now': True}, 'photos': [{'height': 3024, "
#  "'html_attributions': ['<a "
#  'href="https://maps.google.com/maps/contrib/108726837382383580383/photos">Jeremy '
#  "Swartz</a>'], 'photo_reference': "
#  "'CmRaAAAAKthyxPpJw2v7vjRlb9NXntpP7JKmSM-VgviiryizLnxFlBl8PExUQWxkC_8bchG75FzIbQ3o9yUBzwJM26KGY_sQVV4LEU3kJnad7DnSBYQb1mz9TVH-1zkXlzRxalwPEhD81CmUL1vAV1nE8Dt0J-VZGhRy0eEVG6iOlgQGZDDl5uAGJxUyAA', "
#  "'width': 4032}], 'place_id': 'ChIJ1zoUGxYE9YgRL399jlxWp6Q', 'plus_code': "
#  "{'compound_code': 'QJHJ+VX Atlanta, Georgia, United States', 'global_code': "
#  "'865QQJHJ+VX'}, 'price_level': 2, 'rating': 4.7, 'reference': "
#  "'ChIJ1zoUGxYE9YgRL399jlxWp6Q', 'scope': 'GOOGLE', 'types': "
#  "['grocery_or_supermarket', 'florist', 'supermarket', 'liquor_store', "
#  "'store', 'health', 'food', 'point_of_interest', 'establishment'], "
#  "'vicinity': '931 Monroe Drive Northeast, Atlanta'}], 'status': 'OK'}")
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-7ab85e5a660f> in <module>()
#      40
#      41 # Print the name and address of the first bike shop to appear
# ---> 42 print(seattle_bikes["results"][0]["name"])
#      43 print(seattle_bikes["results"][0]["vicinity"])
#
# NameError: name 'seattle_bikes' is not defined
